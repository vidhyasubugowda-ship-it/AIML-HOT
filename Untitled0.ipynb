# %%
print(4+5)
# Out:
# 9

# %%
print(4-4)
# Out:
# 0

# %%
print(7*8)
# Out:
# 56

# %%
print(4/4)
# Out:
# 1.0

# %%
print(3//2)
# Out:
# 1

# %%
vidhya='topper'
print(vidhya)
# Out:
# topper

# %%
vidhya1='topper'
vidhya2='of gkvk'
vidhya3=vidhya1+" "+vidhya2
print(vidhya3)
# Out:
# topper of gkvk

# %%
a=b=c=100
print(a)
print(b)
print(c)
# Out:
# 100
# 100
# 100

# %%
x=16
y=16
z=x+y
print(z)
# Out:
# 32

# %%
print(5%4)
# Out:
# 1

# %%
str='vidhya'
print(str*8)
# Out:
# vidhyavidhyavidhyavidhyavidhyavidhyavidhyavidhya
